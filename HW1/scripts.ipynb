# %%
#Introduction- #Say "Hello, World!" With Python

if __name__ == '__main__':
    string_to_print = "Hello, World!"
    print(string_to_print)

# %%
#Introduction- #Python If-Else

#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
if (n % 2) != 0:
    print("Weird")
else:
    if (n > 20):
        print("Not Weird")
    else:
        if (n >= 6):
            print("Weird")
        else:
            print("Not Weird")

# %%
#Introduction- #Arithmetic Operators

if __name__ == '__main__':
    a = int(input())
    b = int(input())
    
    print(a+b)
    print(a-b)
    print(a*b)

# %%
#Introduction- #Python: Division

if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)

# %%
#Introduction- #Loops

if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i ** 2)

# %%
#Introduction- #Write a function

def is_leap(year):
    leap = False
    
    # Write your logic here
    
    if (year % 4) == 0:
        if (year % 100) == 0:
            if (year % 400) == 0:
                leap = True
            else:
                leap = False
        else:
            leap = True
    else:
        leap = False

# %%
#Introduction- #Print Function

if __name__ == '__main__':
    n = int(input())
    for i in range (1, n+1):
        print(i , end = '')

# %%
#Data types- #List Comprehensions

if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    
    new_list = []
    for i in range(x+1):
        for j in range(y+1):
            for k in range(z+1):
                if (i + j + k) != n:
                    new_list.append([i,j,k])
                else:
                    pass
    
    print(new_list)

# %%
#Data types- Find the Runner-Up Score!

if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    l = list(arr)
    
    winner = max(l[0], l[1])
    runner_up = min(l[0], l[1])
    
    for i in range(2, n):
        if l[i] > winner:
            runner_up = winner
            winner = l[i]
        elif l[i] != winner and l[i] > runner_up:
            runner_up = l[i]
        elif winner == runner_up and runner_up != l[i]:
            runner_up = l[i]
            
    
    print(runner_up)

# %%
#Data types- Nested Lists

if __name__ == '__main__':
    records = []
    scores = []
    names = []
    
    for _ in range(int(input())):
        records.append([])
    
        name = input()
        score = float(input())
        
        records[_].append(name)
        records[_].append(score)
        scores.append(score)
        
    second_lowest_grade = sorted(set(scores))[1]
    
    for i in range(len(records)):
        if records[i][1] == second_lowest_grade:
            names.append(records[i][0])
    
    names.sort()
    for j in range(len(names)):
        print(names[j])

# %%
#Data types- Finding the percentage

if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    
    query_marks = student_marks.get(query_name)
    num_scores = len(query_marks)
    average = sum(query_marks) / num_scores
    
    average_float = "{:.2f}".format(average)
    print(average_float)

# %%
#Data types- Lists

if __name__ == '__main__':
    N = int(input())
    ex_list = []
    commands = []
    
    for i in range(N):
        command = input()
        commands.append(command)
    
    for j in range(N):
        if "insert" in commands[j]:
            string = commands[j]
            num = [int(i) for i in string.split() if i.isdigit()]
            ex_list.insert(int(num[0]), int(num[1]))
        if "print" in commands[j]:
            print(ex_list)
        if "remove" in commands[j]:
            string = commands[j]
            num = [int(i) for i in string.split() if i.isdigit()]
            ex_list.remove(int(num[0]))
        if "append" in commands[j]:
            string = commands[j]
            num = [int(i) for i in string.split() if i.isdigit()]
            ex_list.append(int(num[0]))
        if "sort" in commands[j]:
            ex_list.sort()
        if "pop" in commands[j]:
            ex_list.pop()
        if "reverse" in commands[j]:
            ex_list.reverse()

# %%
#Data types- Tuples

if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    
    t = tuple(integer_list)
    print(hash(t))

# %%
#Strings- sWAP cASE

def swap_case(s):
    result = s.swapcase()
    return result

# %%
#Strings- String Split and Join

def split_and_join(line):
    line = line.split(" ")
    line = "-".join(line)
    return line

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)

# %%
#Strings- What's Your Name?

#
# Complete the 'print_full_name' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. STRING first
#  2. STRING last
#

def print_full_name(first, last):
    print("Hello ", first, " ", last, "! You just delved into python.", sep='')

# %%
#Strings- Mutations

def mutate_string(string, position, character):
    result_l = list(string)
    result_l[position] = character
    result_s = ''.join(result_l)
    return result_s

# %%
#Strings- Find a string

def count_substring(string, sub_string):
    count = 0
    sub_len = len(sub_string)
    for i in range(len(string)):
        if string[i:i+sub_len] == sub_string:
            count += 1
    return count

# %%
#Strings- String Validators

def contains_digit(string):
    return any(char.isdigit() for char in string)

def contains_lowerCase(string):
    return any(char.islower() for char in string)

def contains_upperCase(string):
    return any(char.isupper() for char in string)

if __name__ == '__main__':
    s = input()
    alphanumeric = False
    alphabetical = False
    digit = False
    lowerCase = False
    upperCase = False
    
    if contains_digit(s) == True:
        alphanumeric = True
        digit = True
    
    
    if contains_lowerCase(s) == True:
        alphanumeric = True
        alphabetical = True
        lowerCase = True
    
    if contains_upperCase(s) == True:
        alphanumeric = True
        alphabetical = True
        upperCase = True
    
    print(alphanumeric)
    print(alphabetical)
    print(digit)
    print(lowerCase)
    print(upperCase)

# %%
#Strings- Text Alignment

#Replace all ______ with rjust, ljust or center. 

thickness = int(input()) #This must be an odd number
c = 'H'

#Top Cone
for i in range(thickness):
    print((c*i).rjust(thickness-1)+c+(c*i).ljust(thickness-1))

#Top Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))

#Middle Belt
for i in range((thickness+1)//2):
    print((c*thickness*5).center(thickness*6))    

#Bottom Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))    

#Bottom Cone
for i in range(thickness):
    print(((c*(thickness-i-1)).rjust(thickness)+c+(c*(thickness-i-1)).ljust(thickness)).rjust(thickness*6))

# %%
#Strings- Text Wrap

def wrap(string, max_width):
    arr = [string[i:i + max_width] for i in range(0, len(string), max_width)]
    return '\n'.join(arr)

# %%
#Strings- Designer Door Mat

# Enter your code here. Read input from STDIN. Print output to STDOUT
N, M = map(int, input().split())
for i in range(1, N, 2):
    print(('.|.'*i).center(M, '-'))

print("WELCOME".center(M, '-'))

for j in range(N-2, -1, -2):
    print(('.|.'*j).center(M, '-'))

# %%
#Strings- String Formatting

import math

def print_formatted(number):
    
    for i in range(1, number+1):
        width = len(f"{number:b}")
        print(f"{i:{width}} {i:{width}o} {i:{width}X} {i:{width}b}")

# %%
#Strings- Alphabet Rangoli

def print_rangoli(size):
    # your code goes here
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    l = []
    for i in range(size):
        s = "-".join(alphabet[i:size])
        l.append((s[::-1]+s[1:]).center(4*size-3, "-"))
    print('\n'.join(l[:0:-1]+l))

# %%
#Strings- Capitalize!

# Complete the solve function below.
def solve(s):
    for i in s.split():
        s = s.replace(i,i.capitalize())
    return s

# %%
#Strings- The Minion Game

def minion_game(string):
    # your code goes here
    vowels = 'AEIOU'
    length = len(string)
    stuart_count = 0
    kevin_count = 0
    
    for i in range(length):
        if string[i] in vowels:
            kevin_count += (length - i)
        else:
            stuart_count += (length - i)
    
    if stuart_count > kevin_count:
        print('Stuart', stuart_count)
    elif kevin_count > stuart_count:
        print('Kevin', kevin_count)
    else:
        print('Draw')

# %%
#Strings- Merge the Tools!

def merge_the_tools(string, k):
    # your code goes here
    n = len(string)
    for i in range(0, n-k+1, k):
        p = ""
        for char in string[i: i+k]:
            if char not in p:
                p = p+char
        print(p)

# %%
#Sets- Introduction to Sets

def average(array):
    # your code goes here
    distinct_height = set(array)
    num_distinct_height = len(distinct_height)
    sum_distinct_height = sum(distinct_height)
    
    return round(sum_distinct_height / num_distinct_height, 3)

# %%
#Sets- No Idea!

# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    lengths = input().split()
    array = input().split()
    setA = set(input().split())
    setB = set(input().split())
    my_happiness = 0
    
    for i in range(len(array)):
        if array[i] in setA:
            my_happiness += 1
        elif array[i] in setB:
            my_happiness -= 1
            
    print(my_happiness)

# %%
#Sets- Symmetric Difference

# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    length_set1 = input()
    set1_input = input()
    lenght_set2 = input()
    set2_input = input()
    
    set1 = set(set1_input.split())
    set2 = set(set2_input.split())
    difference1 = set1.difference(set2)
    difference2 = set2.difference(set1)
    length_symmetric_difference = len(difference1) + len(difference2)
    
    symmetric_difference = list(difference1.union(difference2))
    symmetric_difference_int = list(map(int, symmetric_difference))
    symmetric_difference_int.sort()
    for i in range(length_symmetric_difference):
        print(symmetric_difference_int[i])

# %%
#Sets- Set .add()

# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    num_of_stamps = int(input())
    s = set()
    for i in range(num_of_stamps):
        s.add(input())
    print(len(s))

# %%
#Sets- Set .discard(), .remove() & .pop()

n = int(input())
s = set(map(int, input().split()))
num_of_commands = int(input())
for i in range(num_of_commands):
    command = input()
    if "pop" in command and len(s) > 0:
        s.pop()
    elif "remove" in command:
        s.discard(int(command[-1]))
    elif "discard" in command:
        s.discard(int(command[-1]))

print (sum(s))

# %%
#Sets- Set .union() Operation

# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    english_news = int(input())
    english_roll_numbers = set(map(int, input().split()))
    french_news = int(input())
    french_roll_numbers = set(map(int, input().split()))
    
    union = english_roll_numbers.union(french_roll_numbers)
    print(len(union))

# %%
#Sets- Set .intersection() Operation

# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    english_news = int(input())
    english_roll_numbers = set(map(int, input().split()))
    french_news = int(input())
    french_roll_numbers = set(map(int, input().split()))
    
    intersection = english_roll_numbers.intersection(french_roll_numbers)
    print(len(intersection))

# %%
#Sets- Set .difference() Operation

# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    english_news = int(input())
    english_roll_numbers = set(map(int, input().split()))
    french_news = int(input())
    french_roll_numbers = set(map(int, input().split()))
    
    difference = english_roll_numbers.difference(french_roll_numbers)
    print(len(difference))

# %%
#Sets- Set .symmetric_difference() Operation

# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    english_news = int(input())
    english_roll_numbers = set(map(int, input().split()))
    french_news = int(input())
    french_roll_numbers = set(map(int, input().split()))
    
    symmetric_difference = english_roll_numbers.symmetric_difference(french_roll_numbers)
    print(len(symmetric_difference))

# %%
#Sets- Set Mutations

# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    len_A = int(input())
    A = set(map(int, input().split()))
    other_sets = int(input())
    for i in range(other_sets):
        command = input().split()
        new_set = set(map(int, input().split()))
        if command[0] == "update":
            A.update(new_set)
        elif command[0] == "intersection_update":
            A.intersection_update(new_set)
        elif command[0] == "difference_update":
            A.difference_update(new_set)
        elif command[0] == "symmetric_difference_update":
            A.symmetric_difference_update(new_set)
    
    print(sum(A))

# %%
#Sets- The Captain's Room

# Enter your code here. Read input from STDIN. Print output to STDOUT
K = int(input())
room_list = list(map(int, input().split()))
room_list.sort()

for i in range(1,len(room_list)):
        if i != len(room_list) - 1:
            if room_list[i] != room_list[i-1] and room_list[i] != room_list[i+1]:
                print(room_list[i])
                break
        else:
            print(room_list[i])

# %%
#Sets- Check Subset

# Enter your code here. Read input from STDIN. Print output to STDOUT
T = int(input())
for i in range(T):
    lenA = int(input())
    A = set(list(map(int, input().split())))
    lenB = int(input())
    B = set(list(map(int, input().split())))
    print(A.issubset(B))

# %%
#Sets- Check Strict Superset

# Enter your code here. Read input from STDIN. Print output to STDOUT
A = set(list(map(int, input().split())))
n = int(input())
count = 0
for i in range(n):
    new_set = set(list(map(int, input().split())))
    if new_set.issubset(A) and len(A) > len(new_set):
        count += 1
if count == n:
    print("True")
else:
    print("False")

# %%
#Collections- collections.Counter()

# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import Counter 

X = int(input())
shoe_size = list(map(int, input().split()))
N =int(input())
counter = Counter(shoe_size)
money = 0

for i in range(N):
    request = list(map(int, input().split()))
    if counter[request[0]] > 0:
        money += request[-1]
        counter[request[0]] -= 1
print(money)

# %%
#Collections- DefaultDict Tutorial

# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import defaultdict

n, m = list(map(int, input().split()))
A = defaultdict(list)
B = []
for i in range(n):
    A[input()].append(str(i+1))
for j in range(m):
    word = input()
    if word in A:
        print (" ".join(A[word]))
    else:
        print(-1)

# %%
#Collections- Collections.namedtuple()

# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import namedtuple
sum_marks = 0
N = int(input())
columns = list(input().split())
for i in range(N):
    student = list(input().split())
    sum_marks += int(student[columns.index('MARKS')])
print(sum_marks/N)

# %%
#Collections- Collections.OrderedDict()

# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import OrderedDict

n = int(input())
d = OrderedDict()

for _ in range(n):
    item, space, quantity = input().rpartition(' ')
    d[item] = d.get(item, 0) + int(quantity)

for item, quantity in d.items():
    print(item, quantity)

# %%
#Collections- Word Order

# Enter your code here. Read input from STDIN. Print output to STDOUT

from collections import Counter, OrderedDict

class OrderedCounter(Counter, OrderedDict):
    pass

n = int(input())
d = OrderedCounter(input() for _ in range(n))
print(len(d))
print(*d.values())

# %%
#Collections- Collections.deque()

# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import deque

N = int(input())
d = deque()
for i in range(N):
    command = input().split()
    if "pop" == command[0]:
        d.pop()
    elif "popleft" == command[0]:
        d.popleft()
    elif "clear" == command[0]:
        d.clear()
    elif "reverse" == command[0]:
        d.reverse()
    elif "append" == command[0]:
        d.append(command[1])
    elif "appendleft" == command[0]:
        d.appendleft(command[1])
    elif "count" == command[0]:
        d.count(command[1])
    elif "extend" == command[0]:
        d.extend(command[1])
    elif "extendleft" == command[0]:
        d.extendleft(command[1])
    elif "remove" == command[0]:
        d.remove(command[1])
    elif "rotate" == command[0]:
        d.rotate(command[1])

for i in d:
    print(i, end=" ")

# %%
#Collections- Company Logo

#!/bin/python3

import math
import os
import random
import re
import sys
from collections import Counter

if __name__ == '__main__':
    s = input()
    letters = Counter(sorted(s)).most_common(3)
    for i in letters:
        print(*i)

# %%
#Collections- Piling Up!

# Enter your code here. Read input from STDIN. Print output to STDOUT

T = int(input())
for i in range(T):
    n = int(input())
    l = [int(j) for j in input().split()]
    min_index = l.index(min(l))
    left_side = l[:min_index]
    right_side = l[min_index+1:]
    if left_side == sorted(left_side, reverse=True) and right_side == sorted(right_side):
        print("Yes")
    else:
        print("No")

# %%
#Date and Time- Calendar Module

# Enter your code here. Read input from STDIN. Print output to STDOUT
import calendar

date = input().split()
month = int(date[0])
day = int(date[1])
year = int(date[2])

week_day = calendar.weekday(year, month, day)
if (week_day == 0):
    print("MONDAY")
elif (week_day == 1):
    print("TUESDAY")
elif (week_day == 2):
    print("WEDNESDAY")
elif (week_day == 3):
    print("THURSDAY")
elif (week_day == 4):
    print("FRIDAY")
elif (week_day == 5):
    print("SATURDAY")
elif (week_day == 6):
    print("SUNDAY")

# %%
#Date and Time- Time Delta

#!/bin/python3

import math
import os
import random
import re
import sys
from datetime import datetime

# Complete the time_delta function below.
def time_delta(t1, t2):
    t1 = datetime.strptime(t1, "%a %d %B %Y %H:%M:%S %z")
    t2 = datetime.strptime(t2, "%a %d %B %Y %H:%M:%S %z")
    return str(abs(math.floor((t1 - t2).total_seconds())))
    
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()
        t2 = input()

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()

# %%
#Exceptions

# Enter your code here. Read input from STDIN. Print output to STDOUT
T = int(input())
for i in range(T):
    a, b = input().split()
    try:
        print(int(a)//int(b))
    except ZeroDivisionError as e:
        print("Error Code:", e)
    except ValueError as v:
        print("Error Code:", v)

# %%
#Built-ins- Zipped!

# Enter your code here. Read input from STDIN. Print output to STDOUT
from statistics import mean 

N, X = input().split()
result = []

for i in range(int(X)):
    result.append(map(float, input().split()))
for j in zip(*result):
    print(sum(j) / len(j))

# %%
#Built-ins- Athlete Sort

#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    nm = input().split()

    n = int(nm[0])

    m = int(nm[1])

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    k = int(input())
    for i in sorted(arr, key=lambda x: x[k]):
        for j in i:
            print(j, end=" ")
        print(" ", end='\n')

# %%
#Built-ins- ginortS

# Enter your code here. Read input from STDIN. Print output to STDOUT
s = input()
lowercase = []
uppercase = []
odd_digits = []
even_digits =[]

for char in s:
    if char.islower():
        lowercase.append(char)
    if char.isupper():
        uppercase.append(char)
    if char.isdigit():
        if (int(char) % 2) == 0:
            even_digits.append(char)
        else:
            odd_digits.append(char)
print("".join(sorted(lowercase) + sorted(uppercase) + sorted(odd_digits) + sorted(even_digits)))

# %%
#Map and Lambda Function

cube = lambda x: x**3# complete the lambda function 

def fibonacci(n):
    # return a list of fibonacci numbers
    result = []
    if n>=1:
        result.append(0)
        num1 = 0
    if n>=2:
        result.append(1)
        num2 = 1
        next_num = 1
        for i in range(n-2):
            result.append(next_num)
            num1, num2 = num2, next_num
            next_num = num1 + num2
    return result

# %%
#XML- XML 1 - Find the Score

def get_attr_number(node):
    # your code goes here
    return len(node.attrib) + sum(get_attr_number(x) for x in node);

# %%
#XML- XML2 - Find the Maximum Depth

maxdepth = 0
def depth(elem, level):
    global maxdepth
    # your code goes here
    if (level == maxdepth):
        maxdepth += 1
    for child in elem:
        depth(child, level + 1)

# %%
#Closures and Decorations- Standardize Mobile Number Using Decorators

def wrapper(f):
    def fun(l):
        # complete the function
        f(["+91 " + d[-10:-5] + " " + d[-5:] for d in l])
    return fun

# %%
#Closures and Decorations- Decorators 2 - Name Directory

def person_lister(f):
    def inner(people):
        # complete the function
          return [f(p) for p in sorted(people, key = lambda x: (int(x[2])))]
    return inner

# %%
#Numpy- Arrays

def arrays(arr):
    # complete this function
    # use numpy.array
    a = numpy.array(arr, float)
    return numpy.flip(a)

# %%
#Numpy- Shape and Reshape

import numpy

arr = input().split()
a = numpy.array(arr, int)
print(numpy.reshape(a,(3,3)))

# %%
#Numpy- Transpose and Flatten

import numpy as np

N, M = map(int, input().split())
array = np.array([input().split() for i in range(N)], int)
print (np.transpose(array))
print (array.flatten())

# %%
#Numpy- Concatenate

import numpy as np

N, M, P = map(int, input().split())
array = np.array([input().split() for i in range(N+M)], int)
print(array)

# %%
#Numpy- Zeros and Ones

import numpy as np

D = tuple(map(int, input().split()))
print(np.zeros(D, int))
print(np.ones(D, int))

# %%
#Numpy- Eye and Identity

import numpy as np
np.set_printoptions(legacy='1.13')

N, M = map(int, input().split())
print (np.eye(N, M, k = 0))

# %%
#Numpy- Array Mathematics

import numpy as np

N, M = map(int, input().split())
A = np.array([input().split() for i in range(N)], int)
B = np.array([input().split() for j in range(N)], int)
print(np.add(A, B))
print(np.subtract(A, B))
print(np.multiply(A, B))
print(np.floor_divide(A, B))
print(np.mod(A, B))
print(np.power(A, B))

# %%
#Numpy- Floor, Ceil and Rint

import numpy as np
np.set_printoptions(legacy='1.13')
A = np.array(input().split(), float)
print(np.floor(A))
print(np.ceil(A))
print(np.rint(A))

# %%
#Numpy- Sum and Prod

import numpy as np

N, M = map(int, input().split())
array = np.array([input().split() for i in range(N)], int)
print(np.prod(np.sum(array, axis = 0)))

# %%
#Numpy- Min and Max

import numpy as np
N, M = map(int, input().split())
array = np.array([input().split() for i in range(N)], int)
print(np.max(np.min(array, axis = 1)))

# %%
#Numpy- Mean, Var, and Std

import numpy as np
N, M = map(int, input().split())
array = np.array([input().split() for i in range(N)], int)
print(np.mean(array, axis=1))
print(np.var(array, axis=0))
print(round(np.std(array), 11))

# %%
#Numpy- Dot and Cross

import numpy as np

N = int(input())
A = np.array([input().split() for i in range(N)], int)
B = np.array([input().split() for i in range(N)], int)
print(np.matmul(A, B))

# %%
#Numpy- Inner and Outer

import numpy as np
A = np.array(input().split(), int)
B = np.array(input().split(), int)
print(np.inner(A, B))
print(np.outer(A, B))

# %%
#Numpy- Polynomials

import numpy as np

n = list(map(float, input().split()))
x = int(input())
print(np.polyval(n, x))

# %%
#Numpy- Linear Algebra

import numpy as np
N = int(input())
A = np.array([input().split() for i in range(N)], float)
print(round(np.linalg.det(A), 2))

# %%
#Birthday Cake Candles

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'birthdayCakeCandles' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY candles as parameter.
#

def birthdayCakeCandles(candles):
    # Write your code here
    c = 0
    x = max(candles)
    for i in range(len(candles)):
        if candles[i] == x:
            c += 1
    return c
        

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Number Line Jumps

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'kangaroo' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. INTEGER x1
#  2. INTEGER v1
#  3. INTEGER x2
#  4. INTEGER v2
#

def kangaroo(x1, v1, x2, v2):
    # Write your code here
    if v2 > v1:
        return "NO"
    else:
        if v2 == v1:
            return 'NO'
        else:
            if (x1-x2) % (v2-v1) == 0:
                return 'YES'
            else:
                return 'NO'


if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    x1 = int(first_multiple_input[0])

    v1 = int(first_multiple_input[1])

    x2 = int(first_multiple_input[2])

    v2 = int(first_multiple_input[3])

    result = kangaroo(x1, v1, x2, v2)

    fptr.write(result + '\n')

    fptr.close()

# %%
#Viral Advertising

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'viralAdvertising' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER n as parameter.
#

def viralAdvertising(n):
    # Write your code here
    x = 5
    result = 0
    for i in range(n):
        c = math.floor(x/2)
        result += c
        x = c * 3
    return result

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = viralAdvertising(n)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Recursive Digit Sum

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'superDigit' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. STRING n
#  2. INTEGER k
#

def superDigit(n, k):
    # Write your code here
    s = 0
    if (len(n) == 1) and (k == 1):
        return int(n)
    else:
        for digit in n:
            s += int(digit)
        return superDigit(str(s * k), 1)

    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = first_multiple_input[0]

    k = int(first_multiple_input[1])

    result = superDigit(n, k)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Insertion Sort - Part 1

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort1' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort1(n, arr):
    # Write your code here
    valueToInsert = arr[-1]
    index = n-2
    while (valueToInsert < arr[index]) and (index >= 0):
        arr[index+1] = arr[index]
        print(*arr)
        index -= 1
    arr[index+1] = valueToInsert
    print(*arr)
        

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort1(n, arr)

# %%
#Insertion Sort - Part 2

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort2' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#
def insertionSort1(n, arr):
    valueToInsert = arr[-1]
    index = n-2
    while (valueToInsert < arr[index]) and (index >= 0):
        arr[index+1] = arr[index]
        index -= 1
    arr[index+1] = valueToInsert
    return arr
    
    
def insertionSort2(n, arr):
    # Write your code here
    for i in range(1, n):
        arr1 = arr[:i+1]
        arr2 = arr[i+1:]
        arr = insertionSort1(i+1, arr1) + arr2
        print(*arr)
        
        

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort2(n, arr)
